# %% [markdown]
# # Machine Learning / Aprendizagem Automática
#
# ## Diogo Soares, André Falcão and Sara C. Madeira, 2020/21
#
# # ML Project  - Learning about Donations

# %% [markdown]
# ## Logistics
#
# **Students are encouraged to work in teams of 3 people**.
#
# Projects with smaller teams are allowed, in exceptional cases, but will not have better grades for this reason.
#
# The quality of the project will dictate its grade, not the number of people working.
#
# **The project's solution should be uploaded in Moodle before the end of December, 18th (last day before Christmas holidays).**
#
# Students should **upload a `.zip` file** containing all the files necessary for project evaluation.
#
# **It is mandatory to produce a Jupyter notebook containing code and text/images/tables/etc describing the solution and the results. The notebook is both the solution and the report.**
#
# **Decisions should be fundamented and results should be critically discussed.**

# %% [markdown]
# ## Tools
#
# The team should use [Python 3](https://www.python.org) and [Jupyter Notebook](http://jupyter.org), together with **[Scikit-learn](http://scikit-learn.org/stable/)**, **[Orange3](https://orange.biolab.si)**, or **both**.
#
# **[Orange3](https://orange.biolab.si)** can be used through its **[programmatic version](https://docs.orange.biolab.si/3/data-mining-library/)**, by importing and using its packages, or throught its **workflow version**.
#
# **It is up to the team to decide when to use Scikit-learn, Orange, or both.**
#
# In this context, your Jupyter notebook might have a mix of code, results, text explanations, workflow figures, etc.
#
# In case you use Orange/workflows for some tasks you should also deliver the workflow files and explain the options taken in each widget in your notebook.
#
# **You can use this noteboook and the sections below as template for your work.**

# %% [markdown]
# ## Dataset
#
# The dataset to be analysed is **`Donors_dataset.csv`**, made available together with this project description. This dataset, downloaded from [Kaggle](https://www.kaggle.com), contains selected data from the following dataset: [Donors-Prediction](https://www.kaggle.com/momohmustapha/donorsprediction/).
#
#
# **In this project, your team is supposed to use only tabular data (not Images or Image Metadata) and see how far you can go in predicting donations and understanding the donors. You should use both supervised and unsupervised learning to tackled 2 tasks:**
#
# 1. **Task 1 (Supervised Learning) - Predicting Donation and Donation Type**
# 2. **Task 2 (Unsupervised Learning) - Characterizing Donors**
#
# The **`Donors_dataset.csv`** you should learn from has **19.372 instances** described by **50 data fields** that you might use as **categorical/numerical features**
#
# ### File Descriptions
#
# * **Donors_dataset.csv** - Tabular/text data to be used in the machine learning tasks.
#
#
# ### Data Fields
#
# * **CARD_PROM_12** - number of card promotions sent to the individual by the charitable organization in the past 12 months
# * **CLUSTER_CODE** - one of 54 possible cluster codes, which are unique in terms of socioeconomic status, urbanicity, ethnicity, and other demographic characteristics
# * **CONTROL_NUMBER** - unique identifier of each individual
# * **DONOR_AGE** - age as of last year's mail solicitation
# * **DONOR_GENDER** - actual or inferred gender
# * **FILE_AVG_GIFT** - this variable is identical to LIFETIME_AVG_GIFT_AMT
# * **FILE_CARD_GIFT** - lifetime average donation (in \\$) from the individual in response to all card solicitations from the charitable organization
# * **FREQUENCY_STATUS_97NK** - based on the period of recency (determined by RECENCY_STATUS_96NK), which is the past 12 months for all groups except L and E. L and E are 13–24 months ago and 25–36 months ago, respectively: 1 if one donation in this period, 2 if two donations in this period, 3 if three donations in this period, and 4 if four or more donations in this period.
# * **HOME_OWNER** - H if the individual is a homeowner, U if this information is unknown
# * **INCOME_GROUP** - one of 7 possible income level groups based on a number of demographic characteristics
# * **IN_HOUSE** - 1 if the individual has ever donated to the charitable organization's In House program, 0 if not
# * **LAST_GIFT_AMT** - amount of the most recent donation from the individual to the charitable organization
# * **LIFETIME_AVG_GIFT_AMT** - lifetime average donation (in \\$) from the individual to the charitable organization
# * **LIFETIME_CARD_PROM** - total number of card promotions sent to the individual by the charitable organization
# * **LIFETIME_GIFT_AMOUNT** - total lifetime donation amount (in \\$) from the individual to the charitable organization
# * **LIFETIME_GIFT_COUNT** - total number of donations from the individual to the charitable organization
# * **LIFETIME_GIFT_RANGE** - maximum donation amount from the individual minus minimum donation amount from the individual
# * **LIFETIME_MAX_GIFT_AMT** - maximum donation amount (in \\$) from the individual to the charitable organization
# * **LIFETIME_MIN_GIFT_AMT** - minimum donation amount (in \\$) from the individual to the charitable organization
# * **LIFETIME_PROM** - total number of promotions sent to the individual by the charitable organization
# * **MEDIAN_HOME_VALUE** - median home value (in 100\\$) as determined by other input variables
# * **MEDIAN_HOUSEHOLD_INCOME** - median household income (in 100\\$) as determined by other input variables
# * **MONTHS_SINCE_FIRST_GIFT** - number of months since the first donation from the individual to the charitable organization
# * **MONTHS_SINCE_LAST_GIFT** - number of months since the most recent donation from the individual to the charitable organization
# * **MONTHS_SINCE_LAST_PROM_RESP** - number of months since the individual has responded to a promotion by the charitable organization
# * **MONTHS_SINCE_ORIGIN** - number of months that the individual has been in the charitable organization's database
# * **MOR_HIT_RATE** - total number of known times the donor has responded to a mailed solicitation from a group other than the charitable organization
# * **NUMBER_PROM_12** - number of promotions (card or other) sent to the individual by the charitable organization in the past 12 months
# * **OVERLAY_SOURCE** - the data source against which the individual was matched: M if Metromail, P if Polk, B if both
# * **PCT_ATTRIBUTE1** - percent of residents in the neighborhood in which the individual lives that are males and active military
# * **PCT_ATTRIBUTE2** - percent of residents in the neighborhood in which the individual lives that are males and veterans
# * **PCT_ATTRIBUTE3** - percent of residents in the neighborhood in which the individual lives that are Vietnam veterans
# * **PCT_ATTRIBUTE4** - percent of residents in the neighborhood in which the individual lives that are WWII veterans
# * **PCT_OWNER_OCCUPIED** - percent of owner-occupied housing in the neighborhood in which the individual lives
# * **PEP_STAR** - 1 if individual has ever achieved STAR donor status, 0 if not
# * **PER_CAPITA_INCOME** - per capita income (in \\$) of the neighborhood in which the individual lives
# * **PUBLISHED_PHONE** - 1 if the individual's telephone number is published, 0 if not
# * **RECENCY_STATUS_96NK** - recency status as of two years ago: A if active donor, S if star donor, N if new donor, E if inactive donor, F if first time donor, L if lapsing donor
# * **RECENT_AVG_CARD_GIFT_AMT** - average donation from the individual in response to a card solicitation from the charitable organization since four years ago
# * **RECENT_AVG_GIFT_AMT** - average donation (in \\$) from the individual to the charitable organization since four years ago
# * **RECENT_CARD_RESPONSE_COUNT** - number of times the individual has responded to a card solicitation from the charitable organization since four years ago
# * **RECENT_CARD_RESPONSE_PROP** - proportion of responses to the individual to the number of card solicitations from the charitable organization since four years ago
# * **RECENT_RESPONSE_COUNT** - number of times the individual has responded to a promotion (card or other) from the charitable organization since four years ago
# * **RECENT_RESPONSE_PROP** - proportion of responses to the individual to the number of (card or other) solicitations from the charitable organization since four years ago
# * **RECENT_STAR_STATUS** - 1 if individual has achieved star donor status since four years ago, 0 if not
# * **SES** - one of 5 possible socioeconomic codes classifying the neighborhood in which the individual lives
# * **TARGET_B** - 1 if individual donated in response to last year's 97NK mail solicitation from the charitable organization, 0 if individual did not
# * **TARGET_D** - amount of donation (in \\$) from the individual in response to last year's 97NK mail solicitation from the charitable organization
# * **URBANICITY** - classification of the neighborhood in which the individual lives: U if urban, C if city, S if suburban, T if town, R if rural, ? if missing
# * **WEALTH_RATING** - one of 10 possible wealth rating groups based on a number of demographic characteristics
#
#
# ### Donation TYPE
#
# You are supposed to create a new column/feature named `DONATION_TYPE`, whose values describe ranges of the donation amount (DA) reported in feature `TARGET_D`:
# * `A` - DA >= 50
# * `B` - 20 <= DA < 50
# * `C` - 13 <= DA < 20
# * `D` - 10 <= DA < 13
# * `E` - DA < 10
#
#
# ### **Important Notes on Data Cleaning and Preprocessing**
#
#    1. Data can contain **errors/typos**, whose correction might improve the analysis.
#    2. Some features can contain **many values**, whose grouping in categories (aggregation into bins) might improve the analysis.
#    3. Data can contain **missing values**, that you might decide to fill. You might also decide to eliminate instances/features with high percentages of missing values.
#    4. **Not all features are necessarily important** for the analysis.
#    5. Depending on the analysis, **some features might have to be excluded**.
#    6. Class distribution is an important characteristic of the dataset that should be checked. **Class imbalance** might impair machine learning.
#
# Some potentially useful links:
#
# * Data Cleaning and Preprocessing in Scikit-learn: https://scikit-learn.org/stable/modules/preprocessing.html#
# * Data Cleaning and Preprocessing in Orange: https://docs.biolab.si//3/visual-programming/widgets/data/preprocess.html
# * Dealing with imbalance datasets: https://pypi.org/project/imbalanced-learn/ and https://www.kaggle.com/rafjaa/resampling-strategies-for-imbalanced-datasets#t7

# %%
import pandas as pd 
import seaborn as sns
from sklearn import tree
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Task 0 (Know your Data) - Exploratory Data Analysis

# %% [markdown]
# ## Loading Data

# %%
raw_data = pd.read_csv("Donors_dataset.csv")
raw_data
# Out:
#        TARGET_B  TARGET_D  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  \
# 0             0       NaN               5                  101       87.0
# 1             1      10.0              12                  137       79.0
# 2             0       NaN              37                  113       75.0
# 3             0       NaN              38                   92        NaN
# 4             0       NaN              41                  101       74.0
# ...         ...       ...             ...                  ...        ...
# 19367         0       NaN          191687                   89       66.0
# 19368         0       NaN          191710                  137       77.0
# 19369         0       NaN          191746                   29        NaN
# 19370         0       NaN          191775                  129       78.0
# 19371         1     150.0          191779                   29       70.0
#
#        IN_HOUSE URBANICITY SES CLUSTER_CODE HOME_OWNER  ...  \
# 0             0          ?   ?            .          H  ...
# 1             0          R   2           45          H  ...
# 2             0          S   1           11          H  ...
# 3             0          U   2            4          H  ...
# 4             0          R   2           49          U  ...
# ...         ...        ...  ..          ...        ...  ...
# 19367         1          U   1            3          H  ...
# 19368         1          C   1           24          H  ...
# 19369         1          S   1           11          U  ...
# 19370         1          ?   ?            .          U  ...
# 19371         0          ?   ?            .          U  ...
#
#       LIFETIME_GIFT_RANGE  LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  \
# 0                    15.0                   20.0                    5.0
# 1                    20.0                   25.0                    5.0
# 2                    23.0                   28.0                    5.0
# 3                    14.0                   17.0                    3.0
# 4                    20.0                   25.0                    5.0
# ...                   ...                    ...                    ...
# 19367                22.0                   25.0                    3.0
# 19368                 9.0                   10.0                    1.0
# 19369                 0.0                   15.0                   15.0
# 19370                20.0                   25.0                    5.0
# 19371                 0.0                   25.0                   25.0
#
#       LAST_GIFT_AMT  CARD_PROM_12  NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  \
# 0              15.0             5              12                      26
# 1              17.0             7              21                       7
# 2              19.0            11              32                       6
# 3              15.0            11              33                       6
# 4              25.0             6              19                      18
# ...             ...           ...             ...                     ...
# 19367          15.0             6              13                      18
# 19368          10.0             6              13                      21
# 19369          15.0             3               9                      23
# 19370          25.0             7              24                       8
# 19371          25.0             4               9                      24
#
#        MONTHS_SINCE_FIRST_GIFT  FILE_AVG_GIFT  FILE_CARD_GIFT
# 0                           92           8.49               7
# 1                          122          14.72              12
# 2                          105          16.75              16
# 3                           92          11.76              12
# 4                           92           8.83               3
# ...                        ...            ...             ...
# 19367                       81          17.17               3
# 19368                      130           7.81              13
# 19369                       23          15.00               0
# 19370                      129          18.33              11
# 19371                       24          25.00               1
#
# [19372 rows x 50 columns]

# %% [markdown]
# ## Understanding Data

# %% [markdown]
# In this task you should **understand better the features**, their distribution of values, potential errors, etc and plan/describe what data preprocessing steps should be performed next. Very important also is to check the distribution of values in the target (class distribution).
#
# Here you can find a notebook with some examples of what you can do in **Exploratory Data Analysis**: https://www.kaggle.com/artgor/exploration-of-data-step-by-step/notebook. You can also use Orange widgets for this.

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19372 entries, 0 to 19371
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   TARGET_B                     19372 non-null  int64
#  1   TARGET_D                     4843 non-null   float64
#  2   CONTROL_NUMBER               19372 non-null  int64
#  3   MONTHS_SINCE_ORIGIN          19372 non-null  int64
#  4   DONOR_AGE                    14577 non-null  float64
#  5   IN_HOUSE                     19372 non-null  int64
#  6   URBANICITY                   19372 non-null  object
#  7   SES                          19372 non-null  object
#  8   CLUSTER_CODE                 19372 non-null  object
#  9   HOME_OWNER                   19372 non-null  object
#  10  DONOR_GENDER                 19372 non-null  object
#  11  INCOME_GROUP                 14980 non-null  float64
#  12  PUBLISHED_PHONE              19372 non-null  int64
#  13  OVERLAY_SOURCE               19372 non-null  object
#  14  MOR_HIT_RATE                 19372 non-null  int64
#  15  WEALTH_RATING                10562 non-null  float64
#  16  MEDIAN_HOME_VALUE            19372 non-null  int64
#  17  MEDIAN_HOUSEHOLD_INCOME      19372 non-null  int64
#  18  PCT_OWNER_OCCUPIED           19372 non-null  int64
#  19  PER_CAPITA_INCOME            19372 non-null  int64
#  20  PCT_ATTRIBUTE1               19372 non-null  int64
#  21  PCT_ATTRIBUTE2               19372 non-null  int64
#  22  PCT_ATTRIBUTE3               19372 non-null  int64
#  23  PCT_ATTRIBUTE4               19372 non-null  int64
#  24  PEP_STAR                     19372 non-null  int64
#  25  RECENT_STAR_STATUS           19372 non-null  int64
#  26  RECENCY_STATUS_96NK          19372 non-null  object
#  27  FREQUENCY_STATUS_97NK        19372 non-null  int64
#  28  RECENT_RESPONSE_PROP         19372 non-null  float64
#  29  RECENT_AVG_GIFT_AMT          19372 non-null  float64
#  30  RECENT_CARD_RESPONSE_PROP    19372 non-null  float64
#  31  RECENT_AVG_CARD_GIFT_AMT     19372 non-null  float64
#  32  RECENT_RESPONSE_COUNT        19372 non-null  int64
#  33  RECENT_CARD_RESPONSE_COUNT   19372 non-null  int64
#  34  MONTHS_SINCE_LAST_PROM_RESP  19126 non-null  float64
#  35  LIFETIME_CARD_PROM           19372 non-null  int64
#  36  LIFETIME_PROM                19372 non-null  int64
#  37  LIFETIME_GIFT_AMOUNT         19372 non-null  float64
#  38  LIFETIME_GIFT_COUNT          19372 non-null  int64
#  39  LIFETIME_AVG_GIFT_AMT        19372 non-null  float64
#  40  LIFETIME_GIFT_RANGE          19372 non-null  float64
#  41  LIFETIME_MAX_GIFT_AMT        19372 non-null  float64
#  42  LIFETIME_MIN_GIFT_AMT        19372 non-null  float64
#  43  LAST_GIFT_AMT                19372 non-null  float64
#  44  CARD_PROM_12                 19372 non-null  int64
#  45  NUMBER_PROM_12               19372 non-null  int64
#  46  MONTHS_SINCE_LAST_GIFT       19372 non-null  int64
#  47  MONTHS_SINCE_FIRST_GIFT      19372 non-null  int64
#  48  FILE_AVG_GIFT                19372 non-null  float64
#  49  FILE_CARD_GIFT               19372 non-null  int64
# dtypes: float64(16), int64(27), object(7)
# memory usage: 7.4+ MB

# %%
raw_data.describe()
# Out:
#            TARGET_B     TARGET_D  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  \
# count  19372.000000  4843.000000    19372.000000         19372.000000
# mean       0.250000    15.624344    96546.225377            73.409973
# std        0.433024    12.445137    55830.643871            41.255574
# min        0.000000     1.000000        5.000000             5.000000
# 25%        0.000000    10.000000    48289.000000            29.000000
# 50%        0.000000    13.000000    96937.000000            65.000000
# 75%        0.250000    20.000000   145429.500000           113.000000
# max        1.000000   200.000000   191779.000000           137.000000
#
#           DONOR_AGE      IN_HOUSE  INCOME_GROUP  PUBLISHED_PHONE  \
# count  14577.000000  19372.000000  14980.000000     19372.000000
# mean      58.919051      0.073198      3.907543         0.497729
# std       16.669382      0.260469      1.864796         0.500008
# min        0.000000      0.000000      1.000000         0.000000
# 25%       47.000000      0.000000      2.000000         0.000000
# 50%       60.000000      0.000000      4.000000         0.000000
# 75%       73.000000      0.000000      5.000000         1.000000
# max       87.000000      1.000000      7.000000         1.000000
#
#        MOR_HIT_RATE  WEALTH_RATING  ...  LIFETIME_GIFT_RANGE  \
# count  19372.000000   10562.000000  ...         19372.000000
# mean       3.361656       5.005397  ...            11.587876
# std        9.503481       2.815386  ...            15.116893
# min        0.000000       0.000000  ...             0.000000
# 25%        0.000000       3.000000  ...             5.000000
# 50%        0.000000       5.000000  ...            10.000000
# 75%        3.000000       7.000000  ...            15.000000
# max      241.000000       9.000000  ...           997.000000
#
#        LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  \
# count           19372.000000           19372.000000   19372.000000
# mean               19.208808               7.620932      16.584199
# std                16.101128               7.959786      11.977558
# min                 5.000000               0.000000       0.000000
# 25%                12.000000               3.000000      10.000000
# 50%                16.000000               5.000000      15.000000
# 75%                21.000000              10.000000      20.000000
# max              1000.000000             450.000000     450.000000
#
#        CARD_PROM_12  NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  \
# count  19372.000000    19372.000000            19372.000000
# mean       5.367128       12.901869               18.191152
# std        1.264205        4.642072                4.033065
# min        0.000000        2.000000                4.000000
# 25%        5.000000       11.000000               16.000000
# 50%        6.000000       12.000000               18.000000
# 75%        6.000000       13.000000               20.000000
# max       17.000000       64.000000               27.000000
#
#        MONTHS_SINCE_FIRST_GIFT  FILE_AVG_GIFT  FILE_CARD_GIFT
# count             19372.000000   19372.000000    19372.000000
# mean                 69.482088      12.858338        5.273591
# std                  37.568169       8.787758        4.607063
# min                  15.000000       1.360000        0.000000
# 25%                  33.000000       8.000000        2.000000
# 50%                  65.000000      11.200000        4.000000
# 75%                 105.000000      15.000000        8.000000
# max                 260.000000     450.000000       41.000000
#
# [8 rows x 43 columns]

# %%
plt = raw_data['DONOR_GENDER'].value_counts().sort_index().plot(kind = 'barh')
plt.set_title('DONOR_GENDER classes counts')
# Out:
# Text(0.5, 1.0, 'DONOR_GENDER classes counts')

# %%
plt = raw_data['TARGET_B'].value_counts().sort_index().plot(kind = 'barh')
plt.set_title('TARGET_B classes counts')
# Out:
# Text(0.5, 1.0, 'TARGET_B classes counts')

# %%
plt = raw_data['HOME_OWNER'].value_counts().sort_index().plot(kind = 'barh')
plt.set_title('HOME_OWNER classes counts')
# Out:
# Text(0.5, 1.0, 'HOME_OWNER classes counts')

# %%
plt = raw_data['URBANICITY'].value_counts().sort_index().plot(kind = 'barh')
plt.set_title('URBANICITY classes counts')
# Out:
# Text(0.5, 1.0, 'URBANICITY classes counts')

# %%
sns.violinplot(x="TARGET_B", y="DONOR_AGE", data=raw_data)
plt.set_title('TARGET_B by DONOR_AGE and DONOR_GENDER')
# Out:
# Text(0.5, 1.0, 'TARGET_B by DONOR_AGE and DONOR_GENDER')

# %%
sns.violinplot(x="TARGET_B", y="DONOR_AGE", hue="DONOR_GENDER", data=raw_data)
plt.set_title('TARGET_B by DONOR_AGE and DONOR_GENDER')
# Out:
# Text(0.5, 1.0, 'TARGET_B by DONOR_AGE and DONOR_GENDER')

# %%
sns.violinplot(x="TARGET_B", y="DONOR_AGE", hue="HOME_OWNER", data=raw_data)
plt.set_title('TARGET_B by DONOR_AGE and HOME_OWNER')
# Out:
# Text(0.5, 1.0, 'TARGET_B by DONOR_AGE and HOME_OWNER')

# %%
sns.violinplot(x="TARGET_B", y="PER_CAPITA_INCOME", hue="DONOR_GENDER", data=raw_data)
plt.set_title('TARGET_B by PER_CAPITA_INCOME and DONOR_GENDER')
# Out:
# Text(0.5, 1.0, 'TARGET_B by PER_CAPITA_INCOME and DONOR_GENDER')

# %%
sns.violinplot(x="TARGET_B", y="PER_CAPITA_INCOME", data=raw_data)
plt.set_title('TARGET_B by PER_CAPITA_INCOME')
# Out:
# Text(0.5, 1.0, 'TARGET_B by PER_CAPITA_INCOME')

# %% [markdown]
# # Task 1 (Supervised Learning) - Predicting Donation and Donation Type
#
# In this task you should target 3 classification tasks:
# 1. **Predicting  Donation (binary classification task)**;
# 2. **Predicting Donation TYPE (multiclass classification)**; and
# 3. **Train specialized models for SES (socioeconomic classification)**.

# %% [markdown]
# **You should:**
#
# * Choose **one classifier in each category**: Tree models, Rule models, Linear models, Distance-based models, and Probabilistic models.
# * Use cross-validation to evaluate the results.
# * Present and discuss the results for different evaluation measures, present confusion matrices. Remember that not only overall results are important. Check what happens when learning to predict each class.
# * Describe the parameters used for each classifier and how their choice impacted or not the results.
# * Choose the best classifier and fundament you choice.
# * **Discuss critically your choices and the results!**

# %% [markdown]
# ## Preprocessing Data for Classification

# %%
def label_donation_type (row):
    if row['TARGET_D'] >= 50:
        return 'A'
    if row['TARGET_D'] >= 20 and row['TARGET_D'] < 50:
        return 'B'
    if row['TARGET_D'] >= 13 and row['TARGET_D'] < 20:
        return 'C'
    if row['TARGET_D'] >= 10 and row['TARGET_D'] < 13:
        return 'D'
    if row['TARGET_D'] < 10:
        return 'E'
    return '?'

transformed_data = raw_data.copy()
transformed_data['DONATION_TYPE'] = transformed_data.apply (lambda row: label_donation_type(row), axis=1)

transformed_data
# Out:
#        TARGET_B  TARGET_D  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  \
# 0             0       NaN               5                  101       87.0
# 1             1      10.0              12                  137       79.0
# 2             0       NaN              37                  113       75.0
# 3             0       NaN              38                   92        NaN
# 4             0       NaN              41                  101       74.0
# ...         ...       ...             ...                  ...        ...
# 19367         0       NaN          191687                   89       66.0
# 19368         0       NaN          191710                  137       77.0
# 19369         0       NaN          191746                   29        NaN
# 19370         0       NaN          191775                  129       78.0
# 19371         1     150.0          191779                   29       70.0
#
#        IN_HOUSE URBANICITY SES CLUSTER_CODE HOME_OWNER  ...  \
# 0             0          ?   ?            .          H  ...
# 1             0          R   2           45          H  ...
# 2             0          S   1           11          H  ...
# 3             0          U   2            4          H  ...
# 4             0          R   2           49          U  ...
# ...         ...        ...  ..          ...        ...  ...
# 19367         1          U   1            3          H  ...
# 19368         1          C   1           24          H  ...
# 19369         1          S   1           11          U  ...
# 19370         1          ?   ?            .          U  ...
# 19371         0          ?   ?            .          U  ...
#
#       LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  \
# 0                      20.0                    5.0           15.0
# 1                      25.0                    5.0           17.0
# 2                      28.0                    5.0           19.0
# 3                      17.0                    3.0           15.0
# 4                      25.0                    5.0           25.0
# ...                     ...                    ...            ...
# 19367                  25.0                    3.0           15.0
# 19368                  10.0                    1.0           10.0
# 19369                  15.0                   15.0           15.0
# 19370                  25.0                    5.0           25.0
# 19371                  25.0                   25.0           25.0
#
#       CARD_PROM_12  NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  \
# 0                5              12                      26
# 1                7              21                       7
# 2               11              32                       6
# 3               11              33                       6
# 4                6              19                      18
# ...            ...             ...                     ...
# 19367            6              13                      18
# 19368            6              13                      21
# 19369            3               9                      23
# 19370            7              24                       8
# 19371            4               9                      24
#
#        MONTHS_SINCE_FIRST_GIFT  FILE_AVG_GIFT  FILE_CARD_GIFT  DONATION_TYPE
# 0                           92           8.49               7              ?
# 1                          122          14.72              12              D
# 2                          105          16.75              16              ?
# 3                           92          11.76              12              ?
# 4                           92           8.83               3              ?
# ...                        ...            ...             ...            ...
# 19367                       81          17.17               3              ?
# 19368                      130           7.81              13              ?
# 19369                       23          15.00               0              ?
# 19370                      129          18.33              11              ?
# 19371                       24          25.00               1              A
#
# [19372 rows x 51 columns]

# %% [markdown]
# ### Drop TARGET_D because it is replaced by DONATION_TYPE

# %%
transformed_data = transformed_data.drop(columns = ("TARGET_D"))

# %%
plt = transformed_data['DONATION_TYPE'].value_counts().sort_index().plot(kind = 'barh')
plt.set_title('DONATION_TYPE classes counts')
# Out:
# Text(0.5, 1.0, 'DONATION_TYPE classes counts')

# %%
sns.violinplot(x="TARGET_B", y="DONOR_AGE", hue="DONATION_TYPE", data=transformed_data)
plt.set_title('TARGET_B by DONOR_AGE and DONATION_TYPE')
# Out:
# Text(0.5, 1.0, 'TARGET_B by DONOR_AGE and DONATION_TYPE')

# %% [markdown]
# ### Encoding categorical features

# %% [markdown]
# ### replace Nans

# %%
transformed_data.isna().sum()
# Out:
# TARGET_B                       0
# CONTROL_NUMBER                 0
# MONTHS_SINCE_ORIGIN            0
# DONOR_AGE                      0
# IN_HOUSE                       0
# URBANICITY                     0
# SES                            0
# CLUSTER_CODE                   0
# HOME_OWNER                     0
# DONOR_GENDER                   0
# INCOME_GROUP                   0
# PUBLISHED_PHONE                0
# OVERLAY_SOURCE                 0
# MOR_HIT_RATE                   0
# WEALTH_RATING                  0
# MEDIAN_HOME_VALUE              0
# MEDIAN_HOUSEHOLD_INCOME        0
# PCT_OWNER_OCCUPIED             0
# PER_CAPITA_INCOME              0
# PCT_ATTRIBUTE1                 0
# PCT_ATTRIBUTE2                 0
# PCT_ATTRIBUTE3                 0
# PCT_ATTRIBUTE4                 0
# PEP_STAR                       0
# RECENT_STAR_STATUS             0
# RECENCY_STATUS_96NK            0
# FREQUENCY_STATUS_97NK          0
# RECENT_RESPONSE_PROP           0
# RECENT_AVG_GIFT_AMT            0
# RECENT_CARD_RESPONSE_PROP      0
# RECENT_AVG_CARD_GIFT_AMT       0
# RECENT_RESPONSE_COUNT          0
# RECENT_CARD_RESPONSE_COUNT     0
# MONTHS_SINCE_LAST_PROM_RESP    0
# LIFETIME_CARD_PROM             0
# LIFETIME_PROM                  0
# LIFETIME_GIFT_AMOUNT           0
# LIFETIME_GIFT_COUNT            0
# LIFETIME_AVG_GIFT_AMT          0
# LIFETIME_GIFT_RANGE            0
# LIFETIME_MAX_GIFT_AMT          0
# LIFETIME_MIN_GIFT_AMT          0
# LAST_GIFT_AMT                  0
# CARD_PROM_12                   0
# NUMBER_PROM_12                 0
# MONTHS_SINCE_LAST_GIFT         0
# MONTHS_SINCE_FIRST_GIFT        0
# FILE_AVG_GIFT                  0
# FILE_CARD_GIFT                 0
# DONATION_TYPE                  0
# dtype: int64

# %%
#### TODO: 

#transformed_data[transformed_data.isna().any(axis=1)]


# how to replace WEALTH_RATING ? 
# its from 0 to 9 , so missing data could be = 10 
# or replace with a number or with mean ? 
# TODO: try out different values 

transformed_data.WEALTH_RATING =  transformed_data.WEALTH_RATING.fillna(10)


# how to replace DONOR_AGE ? 
# replace with a number or with mean ? 
# first we try mean
# TODO: try out different values 

transformed_data.DONOR_AGE =  transformed_data.DONOR_AGE.fillna((transformed_data.DONOR_AGE.mean()))

# how to replace INCOME_GROUP ? 
# its from 1 to 7 , so missing data could be = 0 
# or replace with a number or with mean ? 
# TODO: try out different values 

# replace with 0 
transformed_data.INCOME_GROUP =  transformed_data.INCOME_GROUP.fillna(0)


# how to replace MONTHS_SINCE_LAST_PROM_RESP ? 
# its from normally : 0 to 36, but also there are negative values ? from -12 to -1 ....
# so missing data could be = -12 or - 13 ?
# or replace with a number or with mean ? 
# TODO: try out different values 
transformed_data.MONTHS_SINCE_LAST_PROM_RESP =  transformed_data.MONTHS_SINCE_LAST_PROM_RESP.fillna(-13.0)


transformed_data.isna().sum()
# Out:
# TARGET_B                       0
# CONTROL_NUMBER                 0
# MONTHS_SINCE_ORIGIN            0
# DONOR_AGE                      0
# IN_HOUSE                       0
# URBANICITY                     0
# SES                            0
# CLUSTER_CODE                   0
# HOME_OWNER                     0
# DONOR_GENDER                   0
# INCOME_GROUP                   0
# PUBLISHED_PHONE                0
# OVERLAY_SOURCE                 0
# MOR_HIT_RATE                   0
# WEALTH_RATING                  0
# MEDIAN_HOME_VALUE              0
# MEDIAN_HOUSEHOLD_INCOME        0
# PCT_OWNER_OCCUPIED             0
# PER_CAPITA_INCOME              0
# PCT_ATTRIBUTE1                 0
# PCT_ATTRIBUTE2                 0
# PCT_ATTRIBUTE3                 0
# PCT_ATTRIBUTE4                 0
# PEP_STAR                       0
# RECENT_STAR_STATUS             0
# RECENCY_STATUS_96NK            0
# FREQUENCY_STATUS_97NK          0
# RECENT_RESPONSE_PROP           0
# RECENT_AVG_GIFT_AMT            0
# RECENT_CARD_RESPONSE_PROP      0
# RECENT_AVG_CARD_GIFT_AMT       0
# RECENT_RESPONSE_COUNT          0
# RECENT_CARD_RESPONSE_COUNT     0
# MONTHS_SINCE_LAST_PROM_RESP    0
# LIFETIME_CARD_PROM             0
# LIFETIME_PROM                  0
# LIFETIME_GIFT_AMOUNT           0
# LIFETIME_GIFT_COUNT            0
# LIFETIME_AVG_GIFT_AMT          0
# LIFETIME_GIFT_RANGE            0
# LIFETIME_MAX_GIFT_AMT          0
# LIFETIME_MIN_GIFT_AMT          0
# LAST_GIFT_AMT                  0
# CARD_PROM_12                   0
# NUMBER_PROM_12                 0
# MONTHS_SINCE_LAST_GIFT         0
# MONTHS_SINCE_FIRST_GIFT        0
# FILE_AVG_GIFT                  0
# FILE_CARD_GIFT                 0
# DONATION_TYPE                  0
# dtype: int64

# %% [markdown]
# ### show Columns that are of the type "object" and need to be transformed to numerical values

# %%
obj_df = transformed_data.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#   URBANICITY SES CLUSTER_CODE HOME_OWNER DONOR_GENDER OVERLAY_SOURCE  \
# 0          ?   ?            .          H            M              P
# 1          R   2           45          H            M              P
# 2          S   1           11          H            F              P
# 3          U   2            4          H            F              B
# 4          R   2           49          U            F              B
#
#   RECENCY_STATUS_96NK DONATION_TYPE
# 0                   A             ?
# 1                   S             D
# 2                   S             ?
# 3                   A             ?
# 4                   A             ?

# %%
lb_make = LabelEncoder()
'''
obj_df["URBANICITY_code"] = lb_make.fit_transform(obj_df["URBANICITY"])
obj_df["SES_code"] = lb_make.fit_transform(obj_df["SES"])
obj_df["CLUSTER_CODE_code"] = lb_make.fit_transform(obj_df["CLUSTER_CODE"])
obj_df["HOME_OWNER_code"] = lb_make.fit_transform(obj_df["HOME_OWNER"])
obj_df["DONOR_GENDER_code"] = lb_make.fit_transform(obj_df["DONOR_GENDER"])
obj_df["OVERLAY_SOURCE_code"] = lb_make.fit_transform(obj_df["OVERLAY_SOURCE"])
obj_df["RECENCY_STATUS_96NK_code"] = lb_make.fit_transform(obj_df["RECENCY_STATUS_96NK"])
obj_df["DONATION_TYPE_code"] = lb_make.fit_transform(obj_df["DONATION_TYPE"])
'''

transformed_data["URBANICITY"] = lb_make.fit_transform(transformed_data["URBANICITY"])
transformed_data["SES"] = lb_make.fit_transform(transformed_data["SES"])
transformed_data["CLUSTER_CODE"] = lb_make.fit_transform(transformed_data["CLUSTER_CODE"])
transformed_data["HOME_OWNER"] = lb_make.fit_transform(transformed_data["HOME_OWNER"])
transformed_data["DONOR_GENDER"] = lb_make.fit_transform(transformed_data["DONOR_GENDER"])
transformed_data["OVERLAY_SOURCE"] = lb_make.fit_transform(transformed_data["OVERLAY_SOURCE"])
transformed_data["RECENCY_STATUS_96NK"] = lb_make.fit_transform(transformed_data["RECENCY_STATUS_96NK"])
transformed_data["DONATION_TYPE"] = lb_make.fit_transform(transformed_data["DONATION_TYPE"])


#obj_df[["URBANICITY", "URBANICITY_code"]].head(10)
#obj_df[["SES", "SES_code"]].head(10)
#obj_df[["CLUSTER_CODE", "CLUSTER_CODE_code"]].head(20)
#obj_df[["HOME_OWNER", "HOME_OWNER_code"]].head(10)
#obj_df[["DONATION_TYPE", "DONATION_TYPE_code"]].head(10)

# %% [markdown]
# ### TODO: Data Cleaning
#
# https://scikit-learn.org/stable/modules/preprocessing.html#
#
# - in progress (Lukas): missing data : Data can contain missing values, that you might decide to fill
# - todo: outlliers
# - todo: errors / typos
# - todo: feature engineering:
#     * You might also decide to eliminate instances/features with high percentages of missing values.
#     * Not all features are necessarily important for the analysis.
#     * Depending on the analysis, some features might have to be excluded
# - todo: is the
#
#
#
# ### Data transformation:
#
# - todo: putting data into bins / clusters
#     * maybe DONOR_AGE ?
# - todo: Class distribution is an important characteristic of the dataset that should be checked. Class imbalance might impair machine learning.
# - todo: Resampling strategies for imbalanced datasets
#     * https://www.kaggle.com/rafjaa/resampling-strategies-for-imbalanced-datasets
#     * https://pypi.org/project/imbalanced-learn/
#     * or extracting same percentages of classes for training and test?

# %% [markdown]
# ### splitting up the datasets

# %%
# delete nans 

#transformed_data = transformed_data.dropna()
#transformed_data = transformed_data.reset_index(drop=True)

#transformed_data.tail()

# %%
train_dataset = transformed_data.sample(frac=0.8,random_state=0)
test_dataset = transformed_data.drop(train_dataset.index)

X_train = train_dataset.drop(columns = ["TARGET_B", "DONATION_TYPE"])
X_test = test_dataset.drop(columns = ["TARGET_B", "DONATION_TYPE"])

y_train_target_b = train_dataset.pop("TARGET_B")
y_test_target_b = test_dataset.pop('TARGET_B')

y_train_donation_type = train_dataset.pop("DONATION_TYPE")
y_test_donation_type = test_dataset.pop('DONATION_TYPE')

# %% [markdown]
# ## Learning Classifiers

# %% [markdown]
# ### Tree models: Descision Trees for predicting Donation

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_
 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(62.78406567096113, 65.80421052631579, 'X[35] <= 49.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(62.621201687378864, 60.0821052631579, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(62.94692965454339, 60.0821052631579, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(63.27265762170791, 71.5263157894737, 'X[2] <= 46.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(63.109793638125645, 65.80421052631579, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(63.43552160529016, 65.80421052631579, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(60.52560027362901, 88.69263157894736, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(60.688464257211265, 94.41473684210527, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(60.06690913236803, 105.85894736842106, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(65.10487743700833, 123.02526315789474, 'X[13] <= 0.5\ngini = 0.173\nsamples = 167\nvalue = [151, 16]'),
#  Text(64.94201345342607, 117.30315789473684, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(65.26774142059058, 117.30315789473684, 'X[19] <= 54.5\ngini = 0.164\nsamples = 166\nvalue = [151, 15]'),
#  Text(65.10487743700833, 111.58105263157894, 'X[16] <= 63.5\ngini = 0.155\nsamples = 165\nvalue = [151, 14]'),
#  Text(64.41270550678372, 105.85894736842106, 'X[2] <= 80.5\ngini = 0.278\nsamples = 48\nvalue = [40, 8]'),
#  Text(64.0869775396192, 100.13684210526316, 'X[29] <= 20.5\ngini = 0.172\nsamples = 42\nvalue = [38, 4]'),
#  Text(63.92411355603694, 94.41473684210527, 'X[14] <= 311.0\ngini = 0.136\nsamples = 41\nvalue = [38, 3]'),
#  Text(63.76124957245469, 88.69263157894736, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(64.0869775396192, 88.69263157894736, 'X[12] <= 7.5\ngini = 0.095\nsamples = 40\nvalue = [38, 2]'),
#  Text(63.92411355603694, 82.97052631578947, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]'),
#  Text(64.24984152320147, 82.97052631578947, 'X[16] <= 60.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(64.0869775396192, 77.24842105263158, 'X[12] <= 8.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(63.92411355603694, 71.5263157894737, 'X[16] <= 48.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(63.76124957245469, 65.80421052631579, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(64.0869775396192, 65.80421052631579, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(64.24984152320147, 71.5263157894737, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(64.41270550678372, 77.24842105263158, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(64.24984152320147, 94.41473684210527, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(64.73843347394825, 100.13684210526316, 'X[36] <= 2.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(64.57556949036598, 94.41473684210527, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(64.9012974575305, 94.41473684210527, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(65.79704936723293, 105.85894736842106, 'X[26] <= 0.375\ngini = 0.097\nsamples = 117\nvalue = [111, 6]'),
#  Text(65.63418538365067, 100.13684210526316, 'X[27] <= 8.915\ngini = 0.082\nsamples = 116\nvalue = [111, 5]'),
#  Text(65.22702542469503, 94.41473684210527, 'X[6] <= 39.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(65.06416144111276, 88.69263157894736, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(65.38988940827728, 88.69263157894736, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(66.04134534260632, 94.41473684210527, 'X[46] <= 16.8\ngini = 0.068\nsamples = 114\nvalue = [110, 4]'),
#  Text(65.7156173754418, 88.69263157894736, 'X[19] <= 49.5\ngini = 0.021\nsamples = 95\nvalue = [94, 1]'),
#  Text(65.55275339185954, 82.97052631578947, 'gini = 0.0\nsamples = 92\nvalue = [92, 0]'),
#  Text(65.87848135902406, 82.97052631578947, 'X[32] <= 18.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(65.7156173754418, 77.24842105263158, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(66.04134534260632, 77.24842105263158, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(66.36707330977084, 88.69263157894736, 'X[2] <= 76.5\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(66.20420932618858, 82.97052631578947, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(66.5299372933531, 82.97052631578947, 'X[21] <= 42.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(66.36707330977084, 77.24842105263158, 'X[6] <= 13.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(66.20420932618858, 71.5263157894737, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(66.5299372933531, 71.5263157894737, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(66.69280127693536, 77.24842105263158, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(65.95991335081519, 100.13684210526316, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(65.43060540417285, 111.58105263157894, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  ...]

# %%
from sklearn.tree import export_text

feature_cols = list(X_train.columns)
r = export_text(clf, feature_names=feature_cols)
print(r)
# Out:
# |--- FREQUENCY_STATUS_97NK <= 2.50
# |   |--- PEP_STAR <= 0.50
# |   |   |--- MEDIAN_HOME_VALUE <= 1772.50
# |   |   |   |--- FILE_AVG_GIFT <= 10.14
# |   |   |   |   |--- PCT_OWNER_OCCUPIED <= 91.50
# |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME <= 141.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME >  141.50
# |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 8049.50
# |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT <= 18.50
# |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP <= 0.27
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP >  0.27
# |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_PROM_RESP <= 16.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_PROM_RESP >  16.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT >  18.50
# |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 7016.50
# |   |   |   |   |   |   |   |   |   |--- HOME_OWNER <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- HOME_OWNER >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  7016.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  8049.50
# |   |   |   |   |   |   |   |--- CONTROL_NUMBER <= 624.00
# |   |   |   |   |   |   |   |   |--- CLUSTER_CODE <= 38.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- CLUSTER_CODE >  38.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- CONTROL_NUMBER >  624.00
# |   |   |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED <= 57.50
# |   |   |   |   |   |   |   |   |   |--- MOR_HIT_RATE <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- DONOR_AGE <= 21.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- DONOR_AGE >  21.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- MOR_HIT_RATE >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE1 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE1 >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED >  57.50
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE1 <= 31.50
# |   |   |   |   |   |   |   |   |   |   |--- CLUSTER_CODE <= 37.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- CLUSTER_CODE >  37.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE1 >  31.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- PCT_OWNER_OCCUPIED >  91.50
# |   |   |   |   |   |--- RECENT_RESPONSE_PROP <= 0.06
# |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED <= 97.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED >  97.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- RECENT_RESPONSE_PROP >  0.06
# |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP <= 0.19
# |   |   |   |   |   |   |   |--- LIFETIME_PROM <= 65.50
# |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_PROM_RESP <= 17.50
# |   |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER <= 58601.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER >  58601.50
# |   |   |   |   |   |   |   |   |   |   |--- MOR_HIT_RATE <= 23.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- MOR_HIT_RATE >  23.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_PROM_RESP >  17.50
# |   |   |   |   |   |   |   |   |   |--- CARD_PROM_12 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- CARD_PROM_12 >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- LIFETIME_PROM >  65.50
# |   |   |   |   |   |   |   |   |--- LIFETIME_PROM <= 70.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- LIFETIME_PROM >  70.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP >  0.19
# |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 646.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  646.50
# |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 1635.00
# |   |   |   |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED <= 92.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED >  92.50
# |   |   |   |   |   |   |   |   |   |   |--- WEALTH_RATING <= 6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- WEALTH_RATING >  6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  1635.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- FILE_AVG_GIFT >  10.14
# |   |   |   |   |--- PER_CAPITA_INCOME <= 11579.00
# |   |   |   |   |   |--- PCT_ATTRIBUTE2 <= 0.50
# |   |   |   |   |   |   |--- CARD_PROM_12 <= 5.50
# |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_PROM_RESP <= 18.50
# |   |   |   |   |   |   |   |   |--- CLUSTER_CODE <= 9.00
# |   |   |   |   |   |   |   |   |   |--- OVERLAY_SOURCE <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- OVERLAY_SOURCE >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- CLUSTER_CODE >  9.00
# |   |   |   |   |   |   |   |   |   |--- HOME_OWNER <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- HOME_OWNER >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_PROM_RESP >  18.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- CARD_PROM_12 >  5.50
# |   |   |   |   |   |   |   |--- LIFETIME_AVG_GIFT_AMT <= 23.03
# |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT <= 71.00
# |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 10396.00
# |   |   |   |   |   |   |   |   |   |   |--- DONOR_GENDER <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- DONOR_GENDER >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  10396.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT >  71.00
# |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_FIRST_GIFT <= 83.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_FIRST_GIFT >  83.50
# |   |   |   |   |   |   |   |   |   |   |--- URBANICITY <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- URBANICITY >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- LIFETIME_AVG_GIFT_AMT >  23.03
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- PCT_ATTRIBUTE2 >  0.50
# |   |   |   |   |   |   |--- INCOME_GROUP <= 2.50
# |   |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT <= 278.00
# |   |   |   |   |   |   |   |   |--- DONOR_AGE <= 86.50
# |   |   |   |   |   |   |   |   |   |--- CLUSTER_CODE <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_PROM_RESP <= 16.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_PROM_RESP >  16.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- CLUSTER_CODE >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 <= 28.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 >  28.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |--- DONOR_AGE >  86.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT >  278.00
# |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER <= 9865.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER >  9865.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- INCOME_GROUP >  2.50
# |   |   |   |   |   |   |   |--- MOR_HIT_RATE <= 2.50
# |   |   |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED <= 86.50
# |   |   |   |   |   |   |   |   |   |--- NUMBER_PROM_12 <= 11.50
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_COUNT <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_COUNT >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- NUMBER_PROM_12 >  11.50
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_MAX_GIFT_AMT <= 28.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_MAX_GIFT_AMT >  28.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED >  86.50
# |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_FIRST_GIFT <= 20.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_FIRST_GIFT >  20.50
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP <= 0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP >  0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- MOR_HIT_RATE >  2.50
# |   |   |   |   |   |   |   |   |--- DONOR_AGE <= 29.50
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_PROM <= 15.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_PROM >  15.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- DONOR_AGE >  29.50
# |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP <= 0.13
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 <= 18.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 >  18.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP >  0.13
# |   |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_ORIGIN <= 23.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_ORIGIN >  23.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |--- PER_CAPITA_INCOME >  11579.00
# |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT <= 24.50
# |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED <= 43.50
# |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 <= 36.50
# |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 <= 34.50
# |   |   |   |   |   |   |   |   |   |--- RECENT_AVG_GIFT_AMT <= 9.16
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- RECENT_AVG_GIFT_AMT >  9.16
# |   |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT <= 10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT >  10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 >  34.50
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT <= 49.50
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_COUNT <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_COUNT >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT >  49.50
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_AVG_GIFT_AMT <= 14.66
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_AVG_GIFT_AMT >  14.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 >  36.50
# |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP <= 0.12
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP >  0.12
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE <= 13.50
# |   |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 11887.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  11887.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE >  13.50
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP <= 0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP >  0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED >  43.50
# |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 <= 55.50
# |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_COUNT <= 13.50
# |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 35207.00
# |   |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 24468.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 24
# |   |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  24468.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  35207.00
# |   |   |   |   |   |   |   |   |   |   |--- FILE_AVG_GIFT <= 13.78
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- FILE_AVG_GIFT >  13.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_COUNT >  13.50
# |   |   |   |   |   |   |   |   |   |--- DONOR_AGE <= 75.50
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 887.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  887.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- DONOR_AGE >  75.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 >  55.50
# |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER <= 100014.00
# |   |   |   |   |   |   |   |   |   |--- OVERLAY_SOURCE <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT <= 22.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT >  22.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- OVERLAY_SOURCE >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER <= 28706.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER >  28706.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER >  100014.00
# |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 705.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  705.00
# |   |   |   |   |   |   |   |   |   |   |--- DONOR_AGE <= 67.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- DONOR_AGE >  67.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT >  24.50
# |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE <= 4.50
# |   |   |   |   |   |   |   |--- CONTROL_NUMBER <= 142272.50
# |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP <= 0.09
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT <= 31.00
# |   |   |   |   |   |   |   |   |   |   |--- CLUSTER_CODE <= 37.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- CLUSTER_CODE >  37.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT >  31.00
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 1120.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  1120.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP >  0.09
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- CONTROL_NUMBER >  142272.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE >  4.50
# |   |   |   |   |   |   |   |--- RECENT_AVG_CARD_GIFT_AMT <= 15.59
# |   |   |   |   |   |   |   |   |--- LIFETIME_CARD_PROM <= 23.50
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 <= 78.50
# |   |   |   |   |   |   |   |   |   |   |--- DONOR_GENDER <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- DONOR_GENDER >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 >  78.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- LIFETIME_CARD_PROM >  23.50
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_CARD_PROM <= 26.50
# |   |   |   |   |   |   |   |   |   |   |--- FILE_AVG_GIFT <= 11.78
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- FILE_AVG_GIFT >  11.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_CARD_PROM >  26.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- RECENT_AVG_CARD_GIFT_AMT >  15.59
# |   |   |   |   |   |   |   |   |--- RECENCY_STATUS_96NK <= 0.50
# |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 1556.00
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_MAX_GIFT_AMT <= 45.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_MAX_GIFT_AMT >  45.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  1556.00
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_MAX_GIFT_AMT <= 17.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_MAX_GIFT_AMT >  17.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- RECENCY_STATUS_96NK >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- MEDIAN_HOME_VALUE >  1772.50
# |   |   |   |--- LIFETIME_PROM <= 10.50
# |   |   |   |   |--- LIFETIME_CARD_PROM <= 3.50
# |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT <= 15.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT >  15.50
# |   |   |   |   |   |   |--- LIFETIME_AVG_GIFT_AMT <= 32.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- LIFETIME_AVG_GIFT_AMT >  32.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- LIFETIME_CARD_PROM >  3.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- LIFETIME_PROM >  10.50
# |   |   |   |   |--- DONOR_AGE <= 67.50
# |   |   |   |   |   |--- PCT_ATTRIBUTE4 <= 13.50
# |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 41472.00
# |   |   |   |   |   |   |   |--- MOR_HIT_RATE <= 10.50
# |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 <= 31.50
# |   |   |   |   |   |   |   |   |   |--- DONOR_GENDER <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED <= 96.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED >  96.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- DONOR_GENDER >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 >  31.50
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 <= 87.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 >  87.50
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP <= 0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP >  0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- MOR_HIT_RATE >  10.50
# |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_FIRST_GIFT <= 43.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_FIRST_GIFT >  43.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  41472.00
# |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP <= 0.05
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP >  0.05
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- PCT_ATTRIBUTE4 >  13.50
# |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 <= 59.00
# |   |   |   |   |   |   |   |--- CONTROL_NUMBER <= 3959.00
# |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_COUNT <= 5.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_COUNT >  5.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- CONTROL_NUMBER >  3959.00
# |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 105322.50
# |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 9779.00
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_AVG_GIFT_AMT <= 13.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_AVG_GIFT_AMT >  13.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  9779.00
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 1782.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  1782.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  105322.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 >  59.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- DONOR_AGE >  67.50
# |   |   |   |   |   |--- FILE_CARD_GIFT <= 4.50
# |   |   |   |   |   |   |--- RECENT_AVG_CARD_GIFT_AMT <= 32.50
# |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 10651.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  10651.50
# |   |   |   |   |   |   |   |   |--- HOME_OWNER <= 0.50
# |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 5161.50
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP <= 0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP >  0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  5161.50
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_AVG_GIFT_AMT <= 22.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_AVG_GIFT_AMT >  22.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- HOME_OWNER >  0.50
# |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 2022.50
# |   |   |   |   |   |   |   |   |   |   |--- FILE_AVG_GIFT <= 12.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- FILE_AVG_GIFT >  12.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  2022.50
# |   |   |   |   |   |   |   |   |   |   |--- LAST_GIFT_AMT <= 11.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- LAST_GIFT_AMT >  11.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- RECENT_AVG_CARD_GIFT_AMT >  32.50
# |   |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT <= 299.50
# |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER <= 159927.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER >  159927.50
# |   |   |   |   |   |   |   |   |   |--- FILE_AVG_GIFT <= 25.78
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FILE_AVG_GIFT >  25.78
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT >  299.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- FILE_CARD_GIFT >  4.50
# |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME <= 324.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME >  324.00
# |   |   |   |   |   |   |   |--- LIFETIME_CARD_PROM <= 31.50
# |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_ORIGIN <= 71.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_ORIGIN >  71.00
# |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT <= 24.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT >  24.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- LIFETIME_CARD_PROM >  31.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |--- PEP_STAR >  0.50
# |   |   |--- LIFETIME_GIFT_COUNT <= 2.50
# |   |   |   |--- class: 1
# |   |   |--- LIFETIME_GIFT_COUNT >  2.50
# |   |   |   |--- MONTHS_SINCE_LAST_GIFT <= 12.50
# |   |   |   |   |--- NUMBER_PROM_12 <= 36.50
# |   |   |   |   |   |--- CONTROL_NUMBER <= 2359.50
# |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 14382.50
# |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP <= 0.37
# |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER <= 1257.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER >  1257.50
# |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_ORIGIN <= 53.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_ORIGIN >  53.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP >  0.37
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  14382.50
# |   |   |   |   |   |   |   |--- RECENT_STAR_STATUS <= 5.50
# |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP <= 0.19
# |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT <= 5.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT >  5.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP >  0.19
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- RECENT_STAR_STATUS >  5.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- CONTROL_NUMBER >  2359.50
# |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 <= 25.50
# |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 <= 55.00
# |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP <= 0.07
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 <= 53.00
# |   |   |   |   |   |   |   |   |   |   |--- NUMBER_PROM_12 <= 34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- NUMBER_PROM_12 >  34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 >  53.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP >  0.07
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_MIN_GIFT_AMT <= 8.00
# |   |   |   |   |   |   |   |   |   |   |--- URBANICITY <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- URBANICITY >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_MIN_GIFT_AMT >  8.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 >  55.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 >  25.50
# |   |   |   |   |   |   |   |--- LIFETIME_MIN_GIFT_AMT <= 17.50
# |   |   |   |   |   |   |   |   |--- RECENCY_STATUS_96NK <= 2.50
# |   |   |   |   |   |   |   |   |   |--- RECENT_STAR_STATUS <= 19.50
# |   |   |   |   |   |   |   |   |   |   |--- CLUSTER_CODE <= 21.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- CLUSTER_CODE >  21.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- RECENT_STAR_STATUS >  19.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- RECENCY_STATUS_96NK >  2.50
# |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP <= 0.10
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP >  0.10
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME <= 342.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME >  342.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- LIFETIME_MIN_GIFT_AMT >  17.50
# |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 <= 21.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 >  21.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- NUMBER_PROM_12 >  36.50
# |   |   |   |   |   |--- DONOR_AGE <= 73.50
# |   |   |   |   |   |   |--- RECENT_AVG_GIFT_AMT <= 25.25
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- RECENT_AVG_GIFT_AMT >  25.25
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- DONOR_AGE >  73.50
# |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 601.00
# |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME <= 232.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME >  232.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  601.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- MONTHS_SINCE_LAST_GIFT >  12.50
# |   |   |   |   |--- CONTROL_NUMBER <= 137894.00
# |   |   |   |   |   |--- LIFETIME_MAX_GIFT_AMT <= 24.50
# |   |   |   |   |   |   |--- LIFETIME_AVG_GIFT_AMT <= 12.57
# |   |   |   |   |   |   |   |--- NUMBER_PROM_12 <= 7.50
# |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP <= 0.09
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP >  0.09
# |   |   |   |   |   |   |   |   |   |--- INCOME_GROUP <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_FIRST_GIFT <= 126.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_FIRST_GIFT >  126.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- INCOME_GROUP >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- NUMBER_PROM_12 >  7.50
# |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER <= 42537.50
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 <= 39.50
# |   |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 50979.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  50979.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 >  39.50
# |   |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_FIRST_GIFT <= 129.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_FIRST_GIFT >  129.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER >  42537.50
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 <= 85.00
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_AVG_CARD_GIFT_AMT <= 4.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_AVG_CARD_GIFT_AMT >  4.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 27
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 >  85.00
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT <= 122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT >  122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- LIFETIME_AVG_GIFT_AMT >  12.57
# |   |   |   |   |   |   |   |--- LAST_GIFT_AMT <= 22.50
# |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 <= 54.50
# |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 2935.00
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 <= 30.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 >  30.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  2935.00
# |   |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 51921.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  51921.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 >  54.50
# |   |   |   |   |   |   |   |   |   |--- HOME_OWNER <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- HOME_OWNER >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- CLUSTER_CODE <= 27.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- CLUSTER_CODE >  27.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- LAST_GIFT_AMT >  22.50
# |   |   |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED <= 81.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED >  81.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- LIFETIME_MAX_GIFT_AMT >  24.50
# |   |   |   |   |   |   |--- MOR_HIT_RATE <= 59.00
# |   |   |   |   |   |   |   |--- RECENT_AVG_CARD_GIFT_AMT <= 23.84
# |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME <= 278.00
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE1 <= 4.00
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP <= 0.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP >  0.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE1 >  4.00
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 <= 20.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 >  20.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME >  278.00
# |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 8551.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  8551.00
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 <= 8.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 >  8.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |--- RECENT_AVG_CARD_GIFT_AMT >  23.84
# |   |   |   |   |   |   |   |   |--- NUMBER_PROM_12 <= 10.50
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_AVG_GIFT_AMT <= 22.81
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE <= 21.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE >  21.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_AVG_GIFT_AMT >  22.81
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- NUMBER_PROM_12 >  10.50
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_MIN_GIFT_AMT <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 777.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  777.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_MIN_GIFT_AMT >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 <= 80.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 >  80.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- MOR_HIT_RATE >  59.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- CONTROL_NUMBER >  137894.00
# |   |   |   |   |   |--- RECENT_RESPONSE_PROP <= 0.12
# |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT <= 55.50
# |   |   |   |   |   |   |   |--- RECENT_AVG_CARD_GIFT_AMT <= 18.75
# |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_FIRST_GIFT <= 41.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_FIRST_GIFT >  41.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- RECENT_AVG_CARD_GIFT_AMT >  18.75
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT >  55.50
# |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 <= 13.50
# |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE1 <= 2.50
# |   |   |   |   |   |   |   |   |   |--- OVERLAY_SOURCE <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- OVERLAY_SOURCE >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- DONOR_AGE <= 52.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- DONOR_AGE >  52.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE1 >  2.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 >  13.50
# |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE <= 48.50
# |   |   |   |   |   |   |   |   |   |--- NUMBER_PROM_12 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- NUMBER_PROM_12 >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- CLUSTER_CODE <= 47.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- CLUSTER_CODE >  47.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE >  48.50
# |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME <= 495.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME >  495.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- RECENT_RESPONSE_PROP >  0.12
# |   |   |   |   |   |   |--- DONOR_AGE <= 70.50
# |   |   |   |   |   |   |   |--- DONOR_GENDER <= 2.50
# |   |   |   |   |   |   |   |   |--- LAST_GIFT_AMT <= 10.50
# |   |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP <= 0.24
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME <= 554.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME >  554.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP >  0.24
# |   |   |   |   |   |   |   |   |   |   |--- INCOME_GROUP <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- INCOME_GROUP >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- LAST_GIFT_AMT >  10.50
# |   |   |   |   |   |   |   |   |   |--- FILE_CARD_GIFT <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- LAST_GIFT_AMT <= 15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- LAST_GIFT_AMT >  15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- FILE_CARD_GIFT >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_MIN_GIFT_AMT <= 0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_MIN_GIFT_AMT >  0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |--- DONOR_GENDER >  2.50
# |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 <= 42.50
# |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT <= 17.50
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP <= 0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP >  0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT >  17.50
# |   |   |   |   |   |   |   |   |   |   |--- NUMBER_PROM_12 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- NUMBER_PROM_12 >  12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 >  42.50
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 <= 13.50
# |   |   |   |   |   |   |   |   |   |   |--- WEALTH_RATING <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- WEALTH_RATING >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 >  13.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DONOR_AGE >  70.50
# |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP <= 0.37
# |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 <= 36.50
# |   |   |   |   |   |   |   |   |   |--- RECENT_AVG_CARD_GIFT_AMT <= 38.67
# |   |   |   |   |   |   |   |   |   |   |--- NUMBER_PROM_12 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- NUMBER_PROM_12 >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- RECENT_AVG_CARD_GIFT_AMT >  38.67
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 >  36.50
# |   |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER <= 175668.00
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 <= 41.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 >  41.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER >  175668.00
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 <= 31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 >  31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP >  0.37
# |   |   |   |   |   |   |   |   |--- RECENT_STAR_STATUS <= 8.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- RECENT_STAR_STATUS >  8.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |--- FREQUENCY_STATUS_97NK >  2.50
# |   |--- LAST_GIFT_AMT <= 8.38
# |   |   |--- MONTHS_SINCE_LAST_PROM_RESP <= 18.50
# |   |   |   |--- CONTROL_NUMBER <= 136639.00
# |   |   |   |   |--- CARD_PROM_12 <= 8.50
# |   |   |   |   |   |--- CARD_PROM_12 <= 4.50
# |   |   |   |   |   |   |--- CLUSTER_CODE <= 25.50
# |   |   |   |   |   |   |   |--- FILE_CARD_GIFT <= 16.50
# |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_COUNT <= 2.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_COUNT >  2.50
# |   |   |   |   |   |   |   |   |   |--- MOR_HIT_RATE <= 11.50
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME <= 98.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME >  98.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- MOR_HIT_RATE >  11.50
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME <= 271.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME >  271.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# ...
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- CONTROL_NUMBER >  102216.50
# |   |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE <= 6.50
# |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME <= 419.00
# |   |   |   |   |   |   |   |   |   |--- FILE_CARD_GIFT <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_COUNT <= 1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_COUNT >  1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- FILE_CARD_GIFT >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME >  419.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE >  6.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- FILE_AVG_GIFT >  8.28
# |   |   |   |   |   |--- PCT_ATTRIBUTE2 <= 48.50
# |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP <= 0.76
# |   |   |   |   |   |   |   |--- MONTHS_SINCE_FIRST_GIFT <= 40.50
# |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE <= 8.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE >  8.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- MONTHS_SINCE_FIRST_GIFT >  40.50
# |   |   |   |   |   |   |   |   |--- LIFETIME_MIN_GIFT_AMT <= 4.50
# |   |   |   |   |   |   |   |   |   |--- DONOR_AGE <= 58.96
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP <= 0.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP >  0.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- DONOR_AGE >  58.96
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- LIFETIME_MIN_GIFT_AMT >  4.50
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 <= 32.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 >  32.50
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP <= 0.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP >  0.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP >  0.76
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- PCT_ATTRIBUTE2 >  48.50
# |   |   |   |   |   |   |--- URBANICITY <= 4.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- URBANICITY >  4.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- RECENT_AVG_GIFT_AMT >  13.71
# |   |   |   |   |--- LIFETIME_GIFT_RANGE <= 10.50
# |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP <= 0.31
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP >  0.31
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- LIFETIME_GIFT_RANGE >  10.50
# |   |   |   |   |   |--- CARD_PROM_12 <= 1.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- CARD_PROM_12 >  1.50
# |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 <= 47.50
# |   |   |   |   |   |   |   |--- LAST_GIFT_AMT <= 28.50
# |   |   |   |   |   |   |   |   |--- NUMBER_PROM_12 <= 3.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- NUMBER_PROM_12 >  3.50
# |   |   |   |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED <= 98.50
# |   |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 31216.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  31216.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED >  98.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- LAST_GIFT_AMT >  28.50
# |   |   |   |   |   |   |   |   |--- PEP_STAR <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- PEP_STAR >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 >  47.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- CARD_PROM_12 >  4.50
# |   |   |   |--- PER_CAPITA_INCOME <= 12327.50
# |   |   |   |   |--- LIFETIME_GIFT_AMOUNT <= 710.00
# |   |   |   |   |   |--- PCT_ATTRIBUTE3 <= 53.50
# |   |   |   |   |   |   |--- LAST_GIFT_AMT <= 15.50
# |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME <= 311.00
# |   |   |   |   |   |   |   |   |--- CLUSTER_CODE <= 26.50
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE <= 18.00
# |   |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 12139.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  12139.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE >  18.00
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP <= 0.20
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP >  0.20
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- CLUSTER_CODE >  26.50
# |   |   |   |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- DONOR_AGE <= 59.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- DONOR_AGE >  59.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 9282.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  9282.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME >  311.00
# |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT <= 16.50
# |   |   |   |   |   |   |   |   |   |--- URBANICITY <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- URBANICITY >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_COUNT <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_COUNT >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT >  16.50
# |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME <= 318.50
# |   |   |   |   |   |   |   |   |   |   |--- FILE_AVG_GIFT <= 7.44
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- FILE_AVG_GIFT >  7.44
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME >  318.50
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 580.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  580.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- LAST_GIFT_AMT >  15.50
# |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT <= 6.50
# |   |   |   |   |   |   |   |   |--- LIFETIME_PROM <= 72.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- LIFETIME_PROM >  72.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT >  6.50
# |   |   |   |   |   |   |   |   |--- CLUSTER_CODE <= 45.00
# |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_PROM_RESP <= 23.50
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_AVG_GIFT_AMT <= 42.83
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_AVG_GIFT_AMT >  42.83
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_PROM_RESP >  23.50
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE <= 26.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE >  26.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- CLUSTER_CODE >  45.00
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_MAX_GIFT_AMT <= 26.00
# |   |   |   |   |   |   |   |   |   |   |--- NUMBER_PROM_12 <= 22.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- NUMBER_PROM_12 >  22.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_MAX_GIFT_AMT >  26.00
# |   |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME <= 8931.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- PER_CAPITA_INCOME >  8931.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- PCT_ATTRIBUTE3 >  53.50
# |   |   |   |   |   |   |--- RECENT_AVG_CARD_GIFT_AMT <= 7.61
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- RECENT_AVG_CARD_GIFT_AMT >  7.61
# |   |   |   |   |   |   |   |--- FILE_CARD_GIFT <= 11.50
# |   |   |   |   |   |   |   |   |--- LIFETIME_MIN_GIFT_AMT <= 9.00
# |   |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP <= 0.23
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_PROP >  0.23
# |   |   |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER <= 117586.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- CONTROL_NUMBER >  117586.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- LIFETIME_MIN_GIFT_AMT >  9.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FILE_CARD_GIFT >  11.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- LIFETIME_GIFT_AMOUNT >  710.00
# |   |   |   |   |   |--- RECENT_AVG_GIFT_AMT <= 23.34
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- RECENT_AVG_GIFT_AMT >  23.34
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- PER_CAPITA_INCOME >  12327.50
# |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT <= 4.50
# |   |   |   |   |   |--- LIFETIME_GIFT_COUNT <= 11.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- LIFETIME_GIFT_COUNT >  11.50
# |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 576.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  576.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- MONTHS_SINCE_LAST_GIFT >  4.50
# |   |   |   |   |   |--- PER_CAPITA_INCOME <= 62578.00
# |   |   |   |   |   |   |--- RECENT_AVG_CARD_GIFT_AMT <= 4.45
# |   |   |   |   |   |   |   |--- INCOME_GROUP <= 6.50
# |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME <= 662.00
# |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 589.00
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME <= 345.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME >  345.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  589.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- MEDIAN_HOUSEHOLD_INCOME >  662.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- INCOME_GROUP >  6.50
# |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP <= 0.19
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP >  0.19
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- RECENT_AVG_CARD_GIFT_AMT >  4.45
# |   |   |   |   |   |   |   |--- MONTHS_SINCE_FIRST_GIFT <= 63.50
# |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 <= 26.50
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 <= 33.50
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP <= 0.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- RECENT_RESPONSE_PROP >  0.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE4 >  33.50
# |   |   |   |   |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED <= 8.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- PCT_OWNER_OCCUPIED >  8.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 >  26.50
# |   |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_COUNT <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 409.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  409.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- RECENT_CARD_RESPONSE_COUNT >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_PROM_RESP <= 17.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- MONTHS_SINCE_LAST_PROM_RESP >  17.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |--- MONTHS_SINCE_FIRST_GIFT >  63.50
# |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE <= 555.50
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE <= 10.50
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 <= 43.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE2 >  43.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- LIFETIME_GIFT_RANGE >  10.50
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 <= 24.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 >  24.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- MEDIAN_HOME_VALUE >  555.50
# |   |   |   |   |   |   |   |   |   |--- WEALTH_RATING <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_MIN_GIFT_AMT <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- LIFETIME_MIN_GIFT_AMT >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- WEALTH_RATING >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 <= 36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- PCT_ATTRIBUTE3 >  36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |--- PER_CAPITA_INCOME >  62578.00
# |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT <= 75.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- LIFETIME_GIFT_AMOUNT >  75.00
# |   |   |   |   |   |   |   |--- class: 1

# %%
y_pred = clf.predict(X_test)
y_pred
# Out:
# array([0, 0, 1, ..., 1, 1, 1])

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6324212700051626

# %%
clf.score(X_train, y_train_target_b)
# Out:
# 1.0

# %%
clf.score(X_test, y_test_target_b)
# Out:
# 0.6324212700051626

# %%
# !pip3 install graphviz

# %%
# !pip3 install pydotplus
# Out:
# Collecting pydotplus
#   Downloading pydotplus-2.0.2.tar.gz (278 kB)
#      |████████████████████████████████| 278 kB 1.6 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.0.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pydotplus) (2.4.7)
# Building wheels for collected packages: pydotplus
#   Building wheel for pydotplus (setup.py) ... done
#   Created wheel for pydotplus: filename=pydotplus-2.0.2-py3-none-any.whl size=24566 sha256=1f3bbc663af870ad2218efb3a4f7ead594a7531f173c9ea30964af2f5900b700
#   Stored in directory: /Users/pflaum/Library/Caches/pip/wheels/fe/cd/78/a7e873cc049759194f8271f780640cf96b35e5a48bef0e2f36
# Successfully built pydotplus
# Installing collected packages: pydotplus
# Successfully installed pydotplus-2.0.2
# WARNING: You are using pip version 20.2.1; however, version 20.2.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3.8 -m pip install --upgrade pip' command.

# %%
from sklearn.tree import export_graphviz
from six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
feature_cols = list(X_train.columns)
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['wont donate','donates'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('donations.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# <ipython-input-65-a53981f9666d> in <module>
#      10                 special_characters=True,feature_names = feature_cols,class_names=['wont donate','donates'])
#      11 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# ---> 12 graph.write_png('donations.png')
#      13 Image(graph.create_png())
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pydotplus/graphviz.py in <lambda>(path, f, prog)
#    1808                 lambda path,
#    1809                 f=frmt,
# -> 1810                 prog=self.prog: self.write(path, format=f, prog=prog)
#    1811             )
#    1812
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pydotplus/graphviz.py in write(self, path, prog, format)
#    1916
#    1917             else:
# -> 1918                 fobj.write(self.create(prog, format))
#    1919         finally:
#    1920             if close:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pydotplus/graphviz.py in create(self, prog, format)
#    1957             self.progs = find_graphviz()
#    1958             if self.progs is None:
# -> 1959                 raise InvocationException(
#    1960                     'GraphViz\'s executables not found')
#    1961
#
# InvocationException: GraphViz's executables not found

# %% [markdown]
# ### Rule models

# %% [markdown]
# ### Linear models

# %% [markdown]
# ### Distance-based models

# %% [markdown]
# ### Probabilistic models

# %% [markdown]
# ## Classification - Results and Discussion

# %% [markdown]
# ...

# %% [markdown]
# # Task 2 (Unsupervised Learning) - Characterizing Donors and Donation Type

# %% [markdown]
# In this task you should **use unsupervised learning algorithms and try to characterize donors (people who really did a donation) and their donation type**. You can use:
# * **Association rule mining** to find **associations between the features and the target Donation/DonationTYPE**.
# * **Clustering algorithms to find similar groups of donors**. Is it possible to find groups of donors with the same/similar DonationTYPE?
# * **Be creative and define your own unsupervised analysis!** What would it be interesting to find out ?

# %% [markdown]
# ## Preprocessing Data for Association Rule Mining

# %% [markdown]
# ...

# %% [markdown]
# ## Finding Associations

# %% [markdown]
# ...

# %% [markdown]
# ## Association Rules - Results and Discussion

# %% [markdown]
# ...

# %% [markdown]
# ## Preprocessing Data for Clustering

# %% [markdown]
# ...

# %% [markdown]
# ## Finding Groups

# %% [markdown]
# ...

# %% [markdown]
# ## Clustering - Results and Discussion

# %% [markdown]
# ...

# %% [markdown]
# # Final Comments and Conclusions

# %% [markdown]
# ...
